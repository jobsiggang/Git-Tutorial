# %% [markdown]
# <a href="https://colab.research.google.com/github/jobsiggang/Git-Tutorial/blob/main/%EC%9B%B9%ED%81%AC%EB%A1%A4%EB%A7%81%EC%98%88%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 웹크롤링 -웹사이트의 정보를 분석하고 수집하는 작업

# %%
import requests
url='http://www.daum.net'
response=requests.get(url)
from bs4 import BeautifulSoup
webpage=response.text
soup=BeautifulSoup(webpage,'html.parser')
favorlist=soup.find_all("a",attrs={'class':'link_favorsch'})
fav=[]
for row in favorlist:
  # print(row.text)
  fav.append(row.text)
print(fav)
# Out:
# ['코로나19 발생현황', '아직낫서른 ost', '14k반지', '이장우 재계약', '사각파이프', '사회적 거리두기', '톡터뷰이 한예리', '스틸그레이팅', '온유 캐스팅', '양도양수']

# %%
import matplotlib.pyplot as plt
a=[10,34,23,78,20]
plt.plot(a)
plt.show()
plt.savefig('result.png')

# %%
from bs4 import BeautifulSoup
from pprint import pprint
import requests

html = requests.get('https://search.naver.com/search.naver?sm=top_hty&fbm=0&ie=utf8&query=%EB%82%A0%EC%94%A8')
#print(html.text)
soup = BeautifulSoup(html.text, 'html.parser')
#data1=soup.find_all('div',{'class':"section_head nx_power"})

data1 = soup.find_all('div',{'class':"section_head nx_power"})
print(data1)
# Out:
# [<div class="section_head nx_power"><h2>파워링크</h2>
# <div class="dsc_ncaution">
# <span><em class="dsc_ncaution_quotation">‘</em><strong class="dsc_ncaution_keyword">날씨</strong><em class="dsc_ncaution_quotation">’</em></span>
# <span class="dsc_ncaution_text">관련 광고입니다.</span>
# <a class="ico_ad_dsc" href="javascript:void(0);" onclick="if(adInfoShowPl(this)) goOtherCR(this, 'a=pwl_nop.adset&amp;r=0&amp;i=pwl_nopadset&amp;u='+urlencode(this.href));" title="이 광고가 표시된 이유">이 광고가 표시된 이유</a>
# <div class="ly_ad_dsc" onclick="adInfoHidePl();" style="display:none">
# <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가이며,
#             이미지 등 추가 링크는 등록한 경우에만 기준에 따라 노출됩니다. <a class="link_help" href="https://saedu.naver.com/help/faq/ncc/view.nhn?faqSeq=704">도움말</a></p>
# <button class="bt_ad_clse" type="button">안내 레이어 닫기</button>
# </div>
# </div>
# ...

# %%
fs = soup.find('span', attrs={'class':"btn_select"})
print(fs)
# Out:
# None

# %% [markdown]
#  wiki에서 Beautifulsoup 검색

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

with urlopen('http://en.wikipedia.org/wiki/Main_Page') as response:
    soup = BeautifulSoup(response, 'html.parser')
    for anchor in soup.find_all('a'):
        print(anchor.get('href', '/'))
# Out:
# /
# #mw-head
# #searchInput
# /wiki/Wikipedia
# /wiki/Free_content
# /wiki/Encyclopedia
# /wiki/Help:Introduction_to_Wikipedia
# /wiki/Special:Statistics
# /wiki/English_language
# /wiki/Portal:The_arts
# /wiki/Portal:Biography
# /wiki/Portal:Geography
# /wiki/Portal:History
# /wiki/Portal:Mathematics
# /wiki/Portal:Science
# /wiki/Portal:Society
# /wiki/Portal:Technology
# /wiki/Wikipedia:Contents/Portals
# /wiki/File:Narrow_Leaf_Drumstick_-_Isopogon_anethifolius_(7970118766).jpg
# /wiki/Isopogon_anethifolius
# /wiki/Shrub
# /wiki/Proteaceae
# /wiki/Endemism
# /wiki/Sydney
# /wiki/Woodland
# /wiki/Heath
# /wiki/Sandstone
# /wiki/Terete
# /wiki/Bushfires_in_Australia
# /wiki/Lignotuber
# /wiki/Species_description
# /wiki/Richard_Anthony_Salisbury
# /wiki/Isopogon
# /wiki/Isopogon_anethifolius
# /wiki/Parks_and_Recreation_(season_1)
# /wiki/Antiochus_XII_Dionysus
# /wiki/R%C3%A9publique-class_battleship
# /wiki/Wikipedia:Today%27s_featured_article/April_2021
# ...

# %%
# -*- coding: UTF-8 -*-
from bs4 import BeautifulSoup
import requests
URL = "http://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=날씨"  #지역별 날씨
html = requests.get(URL).text
soup = BeautifulSoup(html, 'html.parser')
print( requests.get(URL).text)

# %%
find_currenttemp = data1.find('span',{'class': 'todaytemp'}).text
print('현재 온도: '+find_currenttemp+'℃')

data2 = data1.findAll('dd')
find_dust = data2[0].find('span', {'class':'num'}).text
find_ultra_dust = data2[1].find('span', {'class':'num'}).text
find_ozone = data2[2].find('span', {'class':'num'}).text
print('현재 미세먼지: '+find_dust)
print('현재 초미세먼지: '+find_ultra_dust)
print('현재 오존지수: '+find_ozone)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-bf80ea9a9b58> in <module>()
# ----> 1 find_currenttemp = data1.find('span',{'class': 'todaytemp'}).text
#       2 print('현재 온도: '+find_currenttemp+'℃')
#       3
#       4 data2 = data1.findAll('dd')
#       5 find_dust = data2[0].find('span', {'class':'num'}).text
#
# NameError: name 'data1' is not defined

# %%
from bs4 import BeautifulSoup
import requests
ymd=input('궁금한 급식날짜를입력하세요.예20200901')
url='http://daehyun.hs.kr/daehyun-h/M01030701/list?ymd='+ymd
response=requests.get(url)
webpage=response.text
soup=BeautifulSoup(webpage,'html.parser')
meal1=soup.find('a',{'href':'/daehyun-h/M01030701/list?ymd='+ymd}).text
print(meal1)
# Out:
# 궁금한 급식날짜를입력하세요.예2020090120200917
# 17
#
# 중식
#
#
# 흑미밥
# 들깨시락국5.6.13.
# 가지제육불고기5.6.10.13.
# 감자전부추무침5.6.13.
# 배추김치9.13.

# %%
from bs4 import BeautifulSoup
import requests
ymd=input('궁금한 급식날짜를입력하세요.예20200901 :    ')
url='https://school.use.go.kr/hwabong-h/M01030401/list?ymd='+ymd
response=requests.get(url)
webpage=response.text
#print(webpage)
soup=BeautifulSoup(webpage,'html.parser')
meal1=soup.find('a',{'href':'/hwabong-h/M01030401/list?ymd='+ymd}).text
print(meal1)
# Out:
# 궁금한 급식날짜를입력하세요.예20200901 :    20200910
# 10
#
# 중식
#
#
# 보리밥(화봉)
# 참치김치찌개(공고)5.9.13.
# 양배추쌈(화봉)5.6.13.
# 새송이초무침(화봉)5.6.13.
# 돼지갈비찜(화봉)5.6.10.13.18.
# 총각김치(공고)9.13.
# 거봉(공고)

# %%
from bs4 import BeautifulSoup
import requests
url='https://search.daum.net/search?w=tot&DA=YZR&t__nil_searchbox=btn&sug=&sugo=&sq=&o=&q=%EB%82%A0%EC%94%A8'
response=requests.get(url)
webpage=response.text
print(webpage)
soup=BeautifulSoup(webpage,'html.parser')
result=soup.find_all('div',{'class':'info_detail '})
print(result)
for row in result:
  print(row.text)
# Out:
# <!doctype html>
# <html xmlns="http://www.w3.org/1999/xhtml" lang="ko" class="unix unknown ">
# <head profile="http://a9.com/-/spec/opensearch/1.1/">
# <meta http-equiv="content-Type" content="text/html;charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=edge" />
# <meta name="autocomplete" content="off" />
#
# <meta name="referrer" content="always">
#
# <meta name="format-detection" content="telephone=no" />
# <meta property="og:title" content="날씨 &ndash; Daum 검색" />
# <meta property="og:url" content="https://search.daum.net/search?w=tot&q=%EB%82%A0%EC%94%A8" />
# <meta property="og:description" content="Daum 검색에서 날씨에 대한 최신정보를 찾아보세요." />
# <meta property="og:image" content="https://search1.daumcdn.net/search/statics/common/img/og_search.png" />
# <meta property="og:site_name" content="다음검색" />
# <title>날씨 &ndash; Daum 검색</title>
# <link rel="search" type="application/opensearchdescription+xml" href="//search.daum.net/OpenSearch.xml" title="Daum">
# ...

# %%
import requests
from bs4 import BeautifulSoup

# 아래 주소가 메인페이지 내부에서 호출되는 실시간 검색어 데이터를 넘겨주는 주소
# requests.get("주소").json() 을 하면 데이터를 json 형태로 받아올 수 있습니다.
# 아래 주소를 직접 브라우저에서 접속해보시기 바랍니다.
json = requests.get('https://www.naver.com/srchrank?frm=main').json()
print(json)

# json 데이터에서 "data" 항목의 값을 추출
ranks = json.get("data")

# 해당 값은 리스트 형태로 제공되기에 리스트만큼 반복
for r in ranks:
    # 각 데이터는 rank, keyword, keyword_synomyms
    rank = r.get("rank")
    keyword = r.get("keyword")
    print(rank, keyword)
# Out:
# {'ts': '2020-10-04T21:20:00+0900', 'sm': 'agallgrpmamsi0en0sp0', 'rop': [{'ag': 'all'}, {'gr': '01'}, {'ma': '-2'}, {'si': '00'}, {'en': '00'}, {'sp': '00'}], 'data': [{'rank': 1, 'keyword': '하석진 아파트', 'keyword_synonyms': []}, {'rank': 2, 'keyword': '민찬기', 'keyword_synonyms': []}, {'rank': 3, 'keyword': '뭉쳐야 찬다 방송시간', 'keyword_synonyms': ['뭉쳐야찬다']}, {'rank': 4, 'keyword': '오 삼광빌라 등장인물', 'keyword_synonyms': []}, {'rank': 5, 'keyword': '오윤석', 'keyword_synonyms': []}, {'rank': 6, 'keyword': '강경화', 'keyword_synonyms': []}, {'rank': 7, 'keyword': '이일병', 'keyword_synonyms': []}, {'rank': 8, 'keyword': '토트넘 맨유', 'keyword_synonyms': ['맨유 토트넘']}, {'rank': 9, 'keyword': '하석진', 'keyword_synonyms': []}, {'rank': 10, 'keyword': '선을 넘는 녀석들', 'keyword_synonyms': []}, {'rank': 11, 'keyword': '전인화', 'keyword_synonyms': []}, {'rank': 12, 'keyword': '전인화나이', 'keyword_synonyms': []}, {'rank': 13, 'keyword': '전성우', 'keyword_synonyms': []}, {'rank': 14, 'keyword': '김광규', 'keyword_synonyms': []}, {'rank': 
# ...

# %%
import requests
from bs4 import BeautifulSoup

# 아래 주소가 메인페이지 내부에서 호출되는 실시간 검색어 데이터를 넘겨주는 주소
# requests.get("주소").json() 을 하면 데이터를 json 형태로 받아올 수 있습니다.
# 아래 주소를 직접 브라우저에서 접속해보시기 바랍니다.
json = requests.get('https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query=%EB%82%A0%EC%94%A8')
print(json.text)

# json 데이터에서 "data" 항목의 값을 추출
ranks = json.get("data")

# 해당 값은 리스트 형태로 제공되기에 리스트만큼 반복
for r in ranks:
    # 각 데이터는 rank, keyword, keyword_synomyms
    rank = r.get("class")
    keyword = r.get("todaytemp")
    print(rank, keyword)
# Out:
# <!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="날씨 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="'날씨'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="'날씨'의 네이버 통합검색 결과입니다."> <title>날씨 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_200917.css"> <link rel="stylesheet" type="text/css" href="https
# ...
